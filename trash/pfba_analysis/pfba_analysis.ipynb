# %%
import os
import pandas as pd
from pathlib import Path
import plotly.express as px

# two_up =  os.path.abspath(os.path.join(os.getcwd(), "../..", "examples"))
# os.chdir(two_up)

# %%
def analyse_pFBA_results(fname, opname):
    df = pd.read_csv(fname)
    grouped = df.groupby(['Rxn_1_Class', 'Rxn_2_Class']).count()
    grouped['Rxn_2'] /= grouped['Rxn_2'].sum()
    grouped = grouped.rename(columns={'Rxn_1':'Count', 'Rxn_2':'Fraction'})
    grouped = grouped.reset_index()
    grouped["Types"] = grouped["Rxn_1_Class"].str.cat(grouped["Rxn_2_Class"],sep=", ")
    
    fig = px.pie(grouped, values='Fraction', names='Types', title='Reaction pair distribution')
    
    grouped.to_csv("../../results/"+opname+"/"+opname+"_pfBA_segregation.csv")
    fig.write_image("../../results/images/iML1515_pFBA_count.png")
    
    return grouped, fig

# %%
iML1515_results, fig = analyse_pFBA_results('../../examples/iML1515/iML1515_pFBA.csv', opname="iML1515")
print(iML1515_results)
fig.show()

# %%
iNJ661_results, fig = analyse_pFBA_results('iNJ661/iNJ661_pFBA.csv')
display(iNJ661_results)
fig.show()
# Out:
#     Rxn_1_Class   Rxn_2_Class  Count  Fraction                       Types
# 0  pFBAOpt_Rxns      ELE_Rxns     16  0.213333      pFBAOpt_Rxns, ELE_Rxns
# 1  pFBAOpt_Rxns      MLE_Rxns     27  0.360000      pFBAOpt_Rxns, MLE_Rxns
# 2  pFBAOpt_Rxns  pFBAOpt_Rxns     32  0.426667  pFBAOpt_Rxns, pFBAOpt_Rxns

# %%
iPC815_results, fig = analyse_pFBA_results('iPC815/iPC815_pFBA.csv')
display(iPC815_results)
fig.show()
# Out:
#     Rxn_1_Class   Rxn_2_Class  Count  Fraction                       Types
# 0  pFBAOpt_Rxns      ELE_Rxns    117  0.619048      pFBAOpt_Rxns, ELE_Rxns
# 1  pFBAOpt_Rxns      MLE_Rxns     28  0.148148      pFBAOpt_Rxns, MLE_Rxns
# 2  pFBAOpt_Rxns  pFBAOpt_Rxns     44  0.232804  pFBAOpt_Rxns, pFBAOpt_Rxns

# %%
iYL1228_results, fig = analyse_pFBA_results('iYL1228/iYL1228_pFBA.csv')
display(iYL1228_results)
fig.show()
# Out:
#     Rxn_1_Class   Rxn_2_Class  Count  Fraction                       Types
# 0  pFBAOpt_Rxns      ELE_Rxns     20  0.138889      pFBAOpt_Rxns, ELE_Rxns
# 1  pFBAOpt_Rxns      MLE_Rxns     91  0.631944      pFBAOpt_Rxns, MLE_Rxns
# 2  pFBAOpt_Rxns  pFBAOpt_Rxns     33  0.229167  pFBAOpt_Rxns, pFBAOpt_Rxns

# %%
STM_v1_0_results, fig = analyse_pFBA_results('STM_v1_0/STM_v1_0_pFBA.csv')
display(STM_v1_0_results)
fig.show()
# Out:
#     Rxn_1_Class   Rxn_2_Class  Count  Fraction                       Types
# 0      ELE_Rxns      ELE_Rxns    129  0.777108          ELE_Rxns, ELE_Rxns
# 1      ELE_Rxns  pFBAOpt_Rxns      4  0.024096      ELE_Rxns, pFBAOpt_Rxns
# 2      MLE_Rxns      MLE_Rxns      1  0.006024          MLE_Rxns, MLE_Rxns
# 3  pFBAOpt_Rxns      ELE_Rxns     10  0.060241      pFBAOpt_Rxns, ELE_Rxns
# 4  pFBAOpt_Rxns      MLE_Rxns      2  0.012048      pFBAOpt_Rxns, MLE_Rxns
# 5  pFBAOpt_Rxns  pFBAOpt_Rxns     20  0.120482  pFBAOpt_Rxns, pFBAOpt_Rxns

# %%
df = pd.read_csv('iIT341/iIT341_pFBA.csv')
pd.set_option("display.max_rows", None, "display.max_columns", None)
display(df)
# Out:
#       Rxn_1    Rxn_2    Rxn_1_Class   Rxn_2_Class
# 0      ADPT      ADD   pFBAOpt_Rxns      MLE_Rxns
# 1      ADPT    HXPRT   pFBAOpt_Rxns      MLE_Rxns
# 2    ALAD_L    FADOX   pFBAOpt_Rxns      MLE_Rxns
# 3      ANS2      ANS   pFBAOpt_Rxns      MLE_Rxns
# 4      DHPS    FOLD3   pFBAOpt_Rxns      MLE_Rxns
# 5      DHPS     HPPK   pFBAOpt_Rxns      MLE_Rxns
# 6       CAT      CCP   pFBAOpt_Rxns      MLE_Rxns
# 7     GARFT    FTHFD   pFBAOpt_Rxns      MLE_Rxns
# 8      GART   FTHFLi   pFBAOpt_Rxns      ELE_Rxns
# 9     HCO3E  H2CO3D2   pFBAOpt_Rxns      ELE_Rxns
# 10   HEMEti   CPPPGO  ZeroFlux_Rxns  pFBAOpt_Rxns
# 11   HEMEti     FCLT  ZeroFlux_Rxns  pFBAOpt_Rxns
# 12   HEMEti   FE2abc  ZeroFlux_Rxns  pFBAOpt_Rxns
# 13   HEMEti   GLUTRR  ZeroFlux_Rxns  pFBAOpt_Rxns
# 14   HEMEti   GLUTRS  ZeroFlux_Rxns  pFBAOpt_Rxns
# 15   HEMEti    G1SAT  ZeroFlux_Rxns  pFBAOpt_Rxns
# 16   HEMEti     HMBS  ZeroFlux_Rxns  pFBAOpt_Rxns
# 17   HEMEti   PPBNGS  ZeroFlux_Rxns  pFBAOpt_Rxns
# 18   HEMEti    PPPGO  ZeroFlux_Rxns  pFBAOpt_Rxns
# 19   HEMEti    UPP3S  ZeroFlux_Rxns  pFBAOpt_Rxns
# 20   HEMEti   UPPDC1  ZeroFlux_Rxns  pFBAOpt_Rxns
# 21      ME1      AKO   pFBAOpt_Rxns      MLE_Rxns
# 22      ME1    FADOX   pFBAOpt_Rxns      MLE_Rxns
# 23    KAS15   ACOATA   pFBAOpt_Rxns      ELE_Rxns
# 24    KAS15    KAS14   pFBAOpt_Rxns      ELE_Rxns
# 25     NH4t    ARGSL   pFBAOpt_Rxns      MLE_Rxns
# 26     NH4t    ARGSS   pFBAOpt_Rxns      MLE_Rxns
# 27     NH4t     OCBT   pFBAOpt_Rxns      MLE_Rxns
# 28     NH4t    UREAt   pFBAOpt_Rxns      MLE_Rxns
# 29     TKT2      GND   pFBAOpt_Rxns      MLE_Rxns
# 30     TKT2      PGL   pFBAOpt_Rxns      MLE_Rxns
# 31    TRPS1    TRPS2   pFBAOpt_Rxns      ELE_Rxns
# 32    TRPS1    TRPS3   pFBAOpt_Rxns      ELE_Rxns
# 33     UREA    UREAt   pFBAOpt_Rxns      MLE_Rxns
# 34  URIDK2r   DUTPDP   pFBAOpt_Rxns      MLE_Rxns
# 35    RNDR4    DCTPD   pFBAOpt_Rxns      MLE_Rxns
# 36      RPE      GND   pFBAOpt_Rxns      MLE_Rxns
# 37      RPE      PGL   pFBAOpt_Rxns      MLE_Rxns
# 38     ALAR  DALAt2r   pFBAOpt_Rxns  pFBAOpt_Rxns
# 39   ATPS4r     ACKr   pFBAOpt_Rxns  pFBAOpt_Rxns
# 40   ATPS4r    ACt2r   pFBAOpt_Rxns  pFBAOpt_Rxns
# 41     GART    GARFT   pFBAOpt_Rxns  pFBAOpt_Rxns
# 42    G3PD2  G3PD1ir   pFBAOpt_Rxns  pFBAOpt_Rxns
# 43    HCO3E   H2CO3D   pFBAOpt_Rxns      ELE_Rxns
# 44      ME1     FRD5   pFBAOpt_Rxns  pFBAOpt_Rxns
# 45      ME1      FUM   pFBAOpt_Rxns  pFBAOpt_Rxns
# 46     NH4t   ATPS4r   pFBAOpt_Rxns  pFBAOpt_Rxns
# 47     TKT1     TALA   pFBAOpt_Rxns  pFBAOpt_Rxns
# 48     TKT2     TALA   pFBAOpt_Rxns  pFBAOpt_Rxns
# 49     TKT2     TKT1   pFBAOpt_Rxns  pFBAOpt_Rxns
# 50     PTAr   ATPS4r   pFBAOpt_Rxns  pFBAOpt_Rxns
# 51      RPE     TALA   pFBAOpt_Rxns  pFBAOpt_Rxns
# 52      RPE     TKT1   pFBAOpt_Rxns  pFBAOpt_Rxns
# 53      RPE     TKT2   pFBAOpt_Rxns  pFBAOpt_Rxns

# %%
df = pd.read_csv('iML1515/iML1515_pFBA.csv')
pd.set_option("display.max_rows", None, "display.max_columns", None)
display(df)
# Out:
#             Rxn_1         Rxn_2   Rxn_1_Class    Rxn_2_Class
# 0         ALATA_L        VPAMTr  pFBAOpt_Rxns       ELE_Rxns
# 1          CPPPGO       CPPPGO2  pFBAOpt_Rxns       MLE_Rxns
# 2           VALTA        VPAMTr  pFBAOpt_Rxns       ELE_Rxns
# 3            IMPD          XPPT  pFBAOpt_Rxns       MLE_Rxns
# 4            IMPD         HXAND  pFBAOpt_Rxns       MLE_Rxns
# 5          ECOAH4       3OAS100  pFBAOpt_Rxns       MLE_Rxns
# 6          ECOAH4       3OAR100  pFBAOpt_Rxns       MLE_Rxns
# 7          ECOAH4       3HAD100  pFBAOpt_Rxns       MLE_Rxns
# 8          ECOAH1        3HAD80  pFBAOpt_Rxns       MLE_Rxns
# 9          ECOAH1        3HAD40  pFBAOpt_Rxns       MLE_Rxns
# 10         ECOAH1        3OAS60  pFBAOpt_Rxns       MLE_Rxns
# 11         ECOAH1        3OAR60  pFBAOpt_Rxns       MLE_Rxns
# 12         ECOAH1        3OAR80  pFBAOpt_Rxns       MLE_Rxns
# 13         ECOAH1        3OAS80  pFBAOpt_Rxns       MLE_Rxns
# 14         ECOAH1       3OAS100  pFBAOpt_Rxns       MLE_Rxns
# 15         ECOAH1        3OAR40  pFBAOpt_Rxns       MLE_Rxns
# 16         ECOAH1       3OAR100  pFBAOpt_Rxns       MLE_Rxns
# 17         ECOAH1        3HAD60  pFBAOpt_Rxns       MLE_Rxns
# 18         ECOAH1       3HAD100  pFBAOpt_Rxns       MLE_Rxns
# 19         ECOAH2        3HAD80  pFBAOpt_Rxns       MLE_Rxns
# 20         ECOAH2        3HAD40  pFBAOpt_Rxns       MLE_Rxns
# 21         ECOAH2        3OAS60  pFBAOpt_Rxns       MLE_Rxns
# 22         ECOAH2        3OAR60  pFBAOpt_Rxns       MLE_Rxns
# 23         ECOAH2        3OAR80  pFBAOpt_Rxns       MLE_Rxns
# 24         ECOAH2        3OAS80  pFBAOpt_Rxns       MLE_Rxns
# 25         ECOAH2       3OAS100  pFBAOpt_Rxns       MLE_Rxns
# 26         ECOAH2        3OAR40  pFBAOpt_Rxns       MLE_Rxns
# 27         ECOAH2       3OAR100  pFBAOpt_Rxns       MLE_Rxns
# 28         ECOAH2        3HAD60  pFBAOpt_Rxns       MLE_Rxns
# 29         ECOAH2       3HAD100  pFBAOpt_Rxns       MLE_Rxns
# 30         ECOAH3        3HAD80  pFBAOpt_Rxns       MLE_Rxns
# 31         ECOAH3        3HAD40  pFBAOpt_Rxns       MLE_Rxns
# 32         ECOAH3        3OAS60  pFBAOpt_Rxns       MLE_Rxns
# 33         ECOAH3        3OAR60  pFBAOpt_Rxns       MLE_Rxns
# 34         ECOAH3        3OAR80  pFBAOpt_Rxns       MLE_Rxns
# 35         ECOAH3        3OAS80  pFBAOpt_Rxns       MLE_Rxns
# 36         ECOAH3       3OAS100  pFBAOpt_Rxns       MLE_Rxns
# 37         ECOAH3        3OAR40  pFBAOpt_Rxns       MLE_Rxns
# 38         ECOAH3       3OAR100  pFBAOpt_Rxns       MLE_Rxns
# 39         ECOAH3        3HAD60  pFBAOpt_Rxns       MLE_Rxns
# 40         ECOAH3       3HAD100  pFBAOpt_Rxns       MLE_Rxns
# 41            PPC          MALS  pFBAOpt_Rxns       MLE_Rxns
# 42          HACD4       3OAS100  pFBAOpt_Rxns       MLE_Rxns
# 43          HACD4       3OAR100  pFBAOpt_Rxns       MLE_Rxns
# 44          HACD4       3HAD100  pFBAOpt_Rxns       MLE_Rxns
# 45          TRPS3         TRPS1  pFBAOpt_Rxns       MLE_Rxns
# 46          NDPK2          PYK2  pFBAOpt_Rxns   pFBAOpt_Rxns
# 47          NDPK4          PYK6  pFBAOpt_Rxns   pFBAOpt_Rxns
# 48          ASNS2         ASNS1  pFBAOpt_Rxns       MLE_Rxns
# 49          DMPPS         IPDDI  pFBAOpt_Rxns       ELE_Rxns
# 50          IPDPS         IPDDI  pFBAOpt_Rxns       ELE_Rxns
# 51           TRDR         GTHOr  pFBAOpt_Rxns       ELE_Rxns
# 52           TRDR        PAPSR2  pFBAOpt_Rxns       ELE_Rxns
# 53           TRDR          GRXR  pFBAOpt_Rxns       ELE_Rxns
# 54          G3PD2          GLYK  pFBAOpt_Rxns       MLE_Rxns
# 55          G3PD2        ALCD19  pFBAOpt_Rxns       MLE_Rxns
# 56          G3PD2          GAPP  pFBAOpt_Rxns       MLE_Rxns
# 57         AACPS3       3OAR160  pFBAOpt_Rxns       MLE_Rxns
# 58         AACPS3       3OAS160  pFBAOpt_Rxns       MLE_Rxns
# 59         AACPS3       3HAD160  pFBAOpt_Rxns       MLE_Rxns
# 60         AACPS4       3OAS161  pFBAOpt_Rxns       MLE_Rxns
# 61         AACPS4       3HAD161  pFBAOpt_Rxns       MLE_Rxns
# 62         AACPS4       3OAR161  pFBAOpt_Rxns       MLE_Rxns
# 63          PRPPS          R1PK  pFBAOpt_Rxns       ELE_Rxns
# 64          PRPPS        R15BPK  pFBAOpt_Rxns       ELE_Rxns
# 65          PAPSR         GTHOr  pFBAOpt_Rxns       ELE_Rxns
# 66          PAPSR        PAPSR2  pFBAOpt_Rxns       ELE_Rxns
# 67          PAPSR          GRXR  pFBAOpt_Rxns       ELE_Rxns
# 68           GMPS         GMPS2  pFBAOpt_Rxns       MLE_Rxns
# 69        ACACT2r        3HAD80  pFBAOpt_Rxns       MLE_Rxns
# 70        ACACT2r        3HAD40  pFBAOpt_Rxns       MLE_Rxns
# 71        ACACT2r        3OAS60  pFBAOpt_Rxns       MLE_Rxns
# 72        ACACT2r        3OAR60  pFBAOpt_Rxns       MLE_Rxns
# 73        ACACT2r        3OAR80  pFBAOpt_Rxns       MLE_Rxns
# 74        ACACT2r        3OAS80  pFBAOpt_Rxns       MLE_Rxns
# 75        ACACT2r       3OAS100  pFBAOpt_Rxns       MLE_Rxns
# 76        ACACT2r        3OAR40  pFBAOpt_Rxns       MLE_Rxns
# 77        ACACT2r       3OAR100  pFBAOpt_Rxns       MLE_Rxns
# 78        ACACT2r        3HAD60  pFBAOpt_Rxns       MLE_Rxns
# 79        ACACT2r       3HAD100  pFBAOpt_Rxns       MLE_Rxns
# 80        ACACT3r        3HAD80  pFBAOpt_Rxns       MLE_Rxns
# 81        ACACT3r        3HAD40  pFBAOpt_Rxns       MLE_Rxns
# 82        ACACT3r        3OAS60  pFBAOpt_Rxns       MLE_Rxns
# 83        ACACT3r        3OAR60  pFBAOpt_Rxns       MLE_Rxns
# 84        ACACT3r        3OAR80  pFBAOpt_Rxns       MLE_Rxns
# 85        ACACT3r        3OAS80  pFBAOpt_Rxns       MLE_Rxns
# 86        ACACT3r       3OAS100  pFBAOpt_Rxns       MLE_Rxns
# 87        ACACT3r        3OAR40  pFBAOpt_Rxns       MLE_Rxns
# 88        ACACT3r       3OAR100  pFBAOpt_Rxns       MLE_Rxns
# 89        ACACT3r        3HAD60  pFBAOpt_Rxns       MLE_Rxns
# 90        ACACT3r       3HAD100  pFBAOpt_Rxns       MLE_Rxns
# 91        ACACT4r       3OAS100  pFBAOpt_Rxns       MLE_Rxns
# 92        ACACT4r       3OAR100  pFBAOpt_Rxns       MLE_Rxns
# 93        ACACT4r       3HAD100  pFBAOpt_Rxns       MLE_Rxns
# 94          Kt2pp        Kabcpp  pFBAOpt_Rxns       MLE_Rxns
# 95          O2tpp       SUCCtex  pFBAOpt_Rxns       MLE_Rxns
# 96          O2tpp       CPPPGO2  pFBAOpt_Rxns       MLE_Rxns
# 97          HACD1        3HAD80  pFBAOpt_Rxns       MLE_Rxns
# 98          HACD1        3HAD40  pFBAOpt_Rxns       MLE_Rxns
# 99          HACD1        3OAS60  pFBAOpt_Rxns       MLE_Rxns
# 100         HACD1        3OAR60  pFBAOpt_Rxns       MLE_Rxns
# 101         HACD1        3OAR80  pFBAOpt_Rxns       MLE_Rxns
# 102         HACD1        3OAS80  pFBAOpt_Rxns       MLE_Rxns
# 103         HACD1       3OAS100  pFBAOpt_Rxns       MLE_Rxns
# 104         HACD1        3OAR40  pFBAOpt_Rxns       MLE_Rxns
# 105         HACD1       3OAR100  pFBAOpt_Rxns       MLE_Rxns
# 106         HACD1        3HAD60  pFBAOpt_Rxns       MLE_Rxns
# 107         HACD1       3HAD100  pFBAOpt_Rxns       MLE_Rxns
# 108         O2tex       SUCCtex  pFBAOpt_Rxns       MLE_Rxns
# 109         O2tex       CPPPGO2  pFBAOpt_Rxns       MLE_Rxns
# 110         HACD2        3HAD80  pFBAOpt_Rxns       MLE_Rxns
# 111         HACD2        3HAD40  pFBAOpt_Rxns       MLE_Rxns
# 112         HACD2        3OAS60  pFBAOpt_Rxns       MLE_Rxns
# 113         HACD2        3OAR60  pFBAOpt_Rxns       MLE_Rxns
# 114         HACD2        3OAR80  pFBAOpt_Rxns       MLE_Rxns
# 115         HACD2        3OAS80  pFBAOpt_Rxns       MLE_Rxns
# 116         HACD2       3OAS100  pFBAOpt_Rxns       MLE_Rxns
# 117         HACD2        3OAR40  pFBAOpt_Rxns       MLE_Rxns
# 118         HACD2       3OAR100  pFBAOpt_Rxns       MLE_Rxns
# 119         HACD2        3HAD60  pFBAOpt_Rxns       MLE_Rxns
# 120         HACD2       3HAD100  pFBAOpt_Rxns       MLE_Rxns
# 121  GLCtex_copy1  GLCtex_copy2  pFBAOpt_Rxns   pFBAOpt_Rxns
# 122     FACOAE160       3OAR160  pFBAOpt_Rxns       MLE_Rxns
# 123     FACOAE160       3OAS160  pFBAOpt_Rxns       MLE_Rxns
# 124     FACOAE160       3HAD160  pFBAOpt_Rxns       MLE_Rxns
# 125         GLUDy         GLUSy  pFBAOpt_Rxns       MLE_Rxns
# 126         HACD3        3HAD80  pFBAOpt_Rxns       MLE_Rxns
# 127         HACD3        3HAD40  pFBAOpt_Rxns       MLE_Rxns
# 128         HACD3        3OAS60  pFBAOpt_Rxns       MLE_Rxns
# 129         HACD3        3OAR60  pFBAOpt_Rxns       MLE_Rxns
# 130         HACD3        3OAR80  pFBAOpt_Rxns       MLE_Rxns
# 131         HACD3        3OAS80  pFBAOpt_Rxns       MLE_Rxns
# 132         HACD3       3OAS100  pFBAOpt_Rxns       MLE_Rxns
# 133         HACD3        3OAR40  pFBAOpt_Rxns       MLE_Rxns
# 134         HACD3       3OAR100  pFBAOpt_Rxns       MLE_Rxns
# 135         HACD3        3HAD60  pFBAOpt_Rxns       MLE_Rxns
# 136         HACD3       3HAD100  pFBAOpt_Rxns       MLE_Rxns
# 137        DUTPDP        DURIK1  pFBAOpt_Rxns       ELE_Rxns
# 138       ACACT1r        3HAD80  pFBAOpt_Rxns       MLE_Rxns
# 139       ACACT1r        3HAD40  pFBAOpt_Rxns       MLE_Rxns
# 140       ACACT1r        3OAS60  pFBAOpt_Rxns       MLE_Rxns
# 141       ACACT1r        3OAR60  pFBAOpt_Rxns       MLE_Rxns
# 142       ACACT1r        3OAR80  pFBAOpt_Rxns       MLE_Rxns
# 143       ACACT1r        3OAS80  pFBAOpt_Rxns       MLE_Rxns
# 144       ACACT1r       3OAS100  pFBAOpt_Rxns       MLE_Rxns
# 145       ACACT1r        3OAR40  pFBAOpt_Rxns       MLE_Rxns
# 146       ACACT1r       3OAR100  pFBAOpt_Rxns       MLE_Rxns
# 147       ACACT1r        3HAD60  pFBAOpt_Rxns       MLE_Rxns
# 148       ACACT1r       3HAD100  pFBAOpt_Rxns       MLE_Rxns
# 149        AACPS7       3OAR120  pFBAOpt_Rxns       MLE_Rxns
# 150        AACPS7       3HAD120  pFBAOpt_Rxns       MLE_Rxns
# 151        AACPS7       3OAS120  pFBAOpt_Rxns       MLE_Rxns
# 152     FACOAE161       3OAS161  pFBAOpt_Rxns       MLE_Rxns
# 153     FACOAE161       3HAD161  pFBAOpt_Rxns       MLE_Rxns
# 154     FACOAE161       3OAR161  pFBAOpt_Rxns       MLE_Rxns
# 155        PPPGO3         PPPGO  pFBAOpt_Rxns       MLE_Rxns
# 156       PDX5PO2       PDX5POi  pFBAOpt_Rxns       MLE_Rxns
# 157           RPI          TALA  pFBAOpt_Rxns       ELE_Rxns
# 158           RPI        EDTXS1  pFBAOpt_Rxns       MLE_Rxns
# 159           RPI        EDTXS2  pFBAOpt_Rxns       MLE_Rxns
# 160           RPI     LIPAabcpp  pFBAOpt_Rxns       MLE_Rxns
# 161           RPI  ENLIPAabctex  pFBAOpt_Rxns       MLE_Rxns
# 162     FACOAE120       3OAR120  pFBAOpt_Rxns       MLE_Rxns
# 163     FACOAE120       3HAD120  pFBAOpt_Rxns       MLE_Rxns
# 164     FACOAE120       3OAS120  pFBAOpt_Rxns       MLE_Rxns
# 165       SO4t2pp      SULabcpp  pFBAOpt_Rxns       MLE_Rxns
# 166      G3PAT160    APG3PAT160  pFBAOpt_Rxns       ELE_Rxns
# 167      G3PAT160     ACPPAT160  pFBAOpt_Rxns       ELE_Rxns
# 168      G3PAT161     ACPPAT161  pFBAOpt_Rxns       ELE_Rxns
# 169      G3PAT161    APG3PAT161  pFBAOpt_Rxns       ELE_Rxns
# 170        ZN2tpp       ZNabcpp  pFBAOpt_Rxns       MLE_Rxns
# 171        NI2tpp     NI2uabcpp  pFBAOpt_Rxns       MLE_Rxns
# 172       ACOAD3f        3HAD80  pFBAOpt_Rxns       MLE_Rxns
# 173       ACOAD3f        3HAD40  pFBAOpt_Rxns       MLE_Rxns
# 174       ACOAD3f        3OAS60  pFBAOpt_Rxns       MLE_Rxns
# 175       ACOAD3f        3OAR60  pFBAOpt_Rxns       MLE_Rxns
# 176       ACOAD3f        3OAR80  pFBAOpt_Rxns       MLE_Rxns
# 177       ACOAD3f        3OAS80  pFBAOpt_Rxns       MLE_Rxns
# 178       ACOAD3f       3OAS100  pFBAOpt_Rxns       MLE_Rxns
# 179       ACOAD3f        3OAR40  pFBAOpt_Rxns       MLE_Rxns
# 180       ACOAD3f       3OAR100  pFBAOpt_Rxns       MLE_Rxns
# 181       ACOAD3f        3HAD60  pFBAOpt_Rxns       MLE_Rxns
# 182       ACOAD3f       3HAD100  pFBAOpt_Rxns       MLE_Rxns
# 183       ACOAD2f        3HAD80  pFBAOpt_Rxns       MLE_Rxns
# 184       ACOAD2f        3HAD40  pFBAOpt_Rxns       MLE_Rxns
# 185       ACOAD2f        3OAS60  pFBAOpt_Rxns       MLE_Rxns
# 186       ACOAD2f        3OAR60  pFBAOpt_Rxns       MLE_Rxns
# 187       ACOAD2f        3OAR80  pFBAOpt_Rxns       MLE_Rxns
# 188       ACOAD2f        3OAS80  pFBAOpt_Rxns       MLE_Rxns
# 189       ACOAD2f       3OAS100  pFBAOpt_Rxns       MLE_Rxns
# 190       ACOAD2f        3OAR40  pFBAOpt_Rxns       MLE_Rxns
# 191       ACOAD2f       3OAR100  pFBAOpt_Rxns       MLE_Rxns
# 192       ACOAD2f        3HAD60  pFBAOpt_Rxns       MLE_Rxns
# 193       ACOAD2f       3HAD100  pFBAOpt_Rxns       MLE_Rxns
# 194       ACOAD4f       3OAS100  pFBAOpt_Rxns       MLE_Rxns
# 195       ACOAD4f       3OAR100  pFBAOpt_Rxns       MLE_Rxns
# 196       ACOAD4f       3HAD100  pFBAOpt_Rxns       MLE_Rxns
# 197        OPHHX3        OPHHXy  pFBAOpt_Rxns       MLE_Rxns
# 198      DALAt2pp       DALAtex  pFBAOpt_Rxns       MLE_Rxns
# 199        MN2tpp        MNt2pp  pFBAOpt_Rxns       MLE_Rxns
# 200      CLt3_2pp        CLtipp  pFBAOpt_Rxns       MLE_Rxns
# 201          POR5         FLDR2  pFBAOpt_Rxns       MLE_Rxns
# 202      CTECOAI7       3OAS161  pFBAOpt_Rxns       MLE_Rxns
# 203      CTECOAI7       3HAD161  pFBAOpt_Rxns       MLE_Rxns
# 204      CTECOAI7       3OAR161  pFBAOpt_Rxns       MLE_Rxns
# 205       RNTR1c2         NDPK8  pFBAOpt_Rxns       ELE_Rxns
# 206       RNTR2c2         NDPK5  pFBAOpt_Rxns       ELE_Rxns
# 207       I4FE4SR        SCYSDS  pFBAOpt_Rxns       MLE_Rxns
# 208       I4FE4SR       S2FE2SS  pFBAOpt_Rxns       MLE_Rxns
# 209       I4FE4SR       S4FE4SR  pFBAOpt_Rxns       MLE_Rxns
# 210       I4FE4SR       S4FE4ST  pFBAOpt_Rxns       MLE_Rxns
# 211       I4FE4SR      S2FE2SS2  pFBAOpt_Rxns       MLE_Rxns
# 212       RNTR3c2         NDPK7  pFBAOpt_Rxns       MLE_Rxns
# 213       I2FE2SS        SCYSDS  pFBAOpt_Rxns       MLE_Rxns
# 214       I2FE2SS       S2FE2SS  pFBAOpt_Rxns       MLE_Rxns
# 215       I2FE2SS       S4FE4SR  pFBAOpt_Rxns       MLE_Rxns
# 216       I2FE2SS       S2FE2ST  pFBAOpt_Rxns       MLE_Rxns
# 217       I2FE2SS       S4FE4ST  pFBAOpt_Rxns       MLE_Rxns
# 218       I2FE2SS      S2FE2SS2  pFBAOpt_Rxns       MLE_Rxns
# 219       I2FE2ST        SCYSDS  pFBAOpt_Rxns       MLE_Rxns
# 220       I2FE2ST       S2FE2SS  pFBAOpt_Rxns       MLE_Rxns
# 221       I2FE2ST       S2FE2ST  pFBAOpt_Rxns       MLE_Rxns
# 222      I2FE2SS2        SCYSDS  pFBAOpt_Rxns       MLE_Rxns
# 223      I2FE2SS2       S2FE2SS  pFBAOpt_Rxns       MLE_Rxns
# 224      I2FE2SS2       S4FE4SR  pFBAOpt_Rxns       MLE_Rxns
# 225      I2FE2SS2       S4FE4ST  pFBAOpt_Rxns       MLE_Rxns
# 226      I2FE2SS2      S2FE2SS2  pFBAOpt_Rxns       MLE_Rxns
# 227       I4FE4ST        SCYSDS  pFBAOpt_Rxns       MLE_Rxns
# 228       I4FE4ST       S2FE2SS  pFBAOpt_Rxns       MLE_Rxns
# 229       I4FE4ST       S4FE4SR  pFBAOpt_Rxns       MLE_Rxns
# 230       I4FE4ST       S4FE4ST  pFBAOpt_Rxns       MLE_Rxns
# 231       I4FE4ST      S2FE2SS2  pFBAOpt_Rxns       MLE_Rxns
# 232      ACOAD1fr        3HAD80  pFBAOpt_Rxns       MLE_Rxns
# 233      ACOAD1fr        3HAD40  pFBAOpt_Rxns       MLE_Rxns
# 234      ACOAD1fr        3OAS60  pFBAOpt_Rxns       MLE_Rxns
# 235      ACOAD1fr        3OAR60  pFBAOpt_Rxns       MLE_Rxns
# 236      ACOAD1fr        3OAR80  pFBAOpt_Rxns       MLE_Rxns
# 237      ACOAD1fr        3OAS80  pFBAOpt_Rxns       MLE_Rxns
# 238      ACOAD1fr       3OAS100  pFBAOpt_Rxns       MLE_Rxns
# 239      ACOAD1fr        3OAR40  pFBAOpt_Rxns       MLE_Rxns
# 240      ACOAD1fr       3OAR100  pFBAOpt_Rxns       MLE_Rxns
# 241      ACOAD1fr        3HAD60  pFBAOpt_Rxns       MLE_Rxns
# 242      ACOAD1fr       3HAD100  pFBAOpt_Rxns       MLE_Rxns
# 243          AI2K      MTHTHFSs  pFBAOpt_Rxns       MLE_Rxns
# 244          AI2K      DHPTDCs2  pFBAOpt_Rxns       MLE_Rxns
# 245       PIt2rpp      PIuabcpp  pFBAOpt_Rxns       MLE_Rxns
# 246         PAI2I      MTHTHFSs  pFBAOpt_Rxns       MLE_Rxns
# 247         PAI2I      DHPTDCs2  pFBAOpt_Rxns       MLE_Rxns
# 248       I2FE2SR       S2FE2SR  pFBAOpt_Rxns  ZeroFlux_Rxns
# 249         PAI2T      MTHTHFSs  pFBAOpt_Rxns       MLE_Rxns
# 250         PAI2T      DHPTDCs2  pFBAOpt_Rxns       MLE_Rxns
# 251         VALTA       ALATA_L  pFBAOpt_Rxns   pFBAOpt_Rxns
# 252          TKT1           RPE  pFBAOpt_Rxns   pFBAOpt_Rxns
# 253         IPDPS         DMPPS  pFBAOpt_Rxns   pFBAOpt_Rxns
# 254         PRPPS           PPM  pFBAOpt_Rxns   pFBAOpt_Rxns
# 255         GARFT          GART  pFBAOpt_Rxns   pFBAOpt_Rxns
# 256         PSERT        GHMT2r  pFBAOpt_Rxns   pFBAOpt_Rxns
# 257           GND           RPE  pFBAOpt_Rxns   pFBAOpt_Rxns
# 258         PSP_L        GHMT2r  pFBAOpt_Rxns   pFBAOpt_Rxns
# 259         O2tpp           ENO  pFBAOpt_Rxns   pFBAOpt_Rxns
# 260         O2tpp           PGK  pFBAOpt_Rxns   pFBAOpt_Rxns
# 261         O2tpp          GAPD  pFBAOpt_Rxns   pFBAOpt_Rxns
# 262          TKT2           RPE  pFBAOpt_Rxns   pFBAOpt_Rxns
# 263          TKT2          TKT1  pFBAOpt_Rxns   pFBAOpt_Rxns
# 264          TKT2           GND  pFBAOpt_Rxns   pFBAOpt_Rxns
# 265         O2tex           ENO  pFBAOpt_Rxns   pFBAOpt_Rxns
# 266         O2tex           PGK  pFBAOpt_Rxns   pFBAOpt_Rxns
# 267         O2tex          GAPD  pFBAOpt_Rxns   pFBAOpt_Rxns
# 268          PGCD        GHMT2r  pFBAOpt_Rxns   pFBAOpt_Rxns
# 269        PPPGO3         O2tpp  pFBAOpt_Rxns   pFBAOpt_Rxns
# 270        PPPGO3         O2tex  pFBAOpt_Rxns   pFBAOpt_Rxns
# 271       PDX5PO2         O2tpp  pFBAOpt_Rxns   pFBAOpt_Rxns
# 272       PDX5PO2         O2tex  pFBAOpt_Rxns   pFBAOpt_Rxns
# 273           PGM         O2tpp  pFBAOpt_Rxns   pFBAOpt_Rxns
# 274           PGM         O2tex  pFBAOpt_Rxns   pFBAOpt_Rxns
# 275           RPI           RPE  pFBAOpt_Rxns   pFBAOpt_Rxns
# 276           RPI          TKT1  pFBAOpt_Rxns   pFBAOpt_Rxns
# 277           RPI          TKT2  pFBAOpt_Rxns   pFBAOpt_Rxns
# 278        OPHHX3         O2tpp  pFBAOpt_Rxns   pFBAOpt_Rxns
# 279        OPHHX3         O2tex  pFBAOpt_Rxns   pFBAOpt_Rxns
# 280        4HTHRA        OHPBAT  pFBAOpt_Rxns   pFBAOpt_Rxns
# 281        4HTHRA          E4PD  pFBAOpt_Rxns   pFBAOpt_Rxns
# 282        4HTHRA          PERD  pFBAOpt_Rxns   pFBAOpt_Rxns
# 283        4HTHRK        OHPBAT  pFBAOpt_Rxns   pFBAOpt_Rxns
# 284        4HTHRK          E4PD  pFBAOpt_Rxns   pFBAOpt_Rxns
# 285        4HTHRK          PERD  pFBAOpt_Rxns   pFBAOpt_Rxns

# %%
df = pd.read_csv('iNJ661/iNJ661_pFBA.csv')
pd.set_option("display.max_rows", None, "display.max_columns", None)
display(df)
# Out:
#           Rxn_1       Rxn_2   Rxn_1_Class   Rxn_2_Class
# 0          THRS      THRD_L  pFBAOpt_Rxns      ELE_Rxns
# 1         PUNP5       HXPRT  pFBAOpt_Rxns      MLE_Rxns
# 2           PIt       PIabc  pFBAOpt_Rxns      MLE_Rxns
# 3       PREPTTA   PREPHACPH  pFBAOpt_Rxns      MLE_Rxns
# 4          SADT       SADT2  pFBAOpt_Rxns      MLE_Rxns
# 5         P5CRx        P5CR  pFBAOpt_Rxns      ELE_Rxns
# 6           RPE         PGL  pFBAOpt_Rxns      MLE_Rxns
# 7           RPE     G6PDH2r  pFBAOpt_Rxns      MLE_Rxns
# 8           RPE         GND  pFBAOpt_Rxns      MLE_Rxns
# 9         TRPS1       TRPS3  pFBAOpt_Rxns      ELE_Rxns
# 10        TRPS1       TRPS2  pFBAOpt_Rxns      ELE_Rxns
# 11       MANAT2     G16MTM2  pFBAOpt_Rxns  pFBAOpt_Rxns
# 12        IPDPS       IPDDI  pFBAOpt_Rxns      ELE_Rxns
# 13      MAN1PT2      MAN1PT  pFBAOpt_Rxns      MLE_Rxns
# 14         TKT2         PGL  pFBAOpt_Rxns      MLE_Rxns
# 15         TKT2     G6PDH2r  pFBAOpt_Rxns      MLE_Rxns
# 16         TKT2         GND  pFBAOpt_Rxns      MLE_Rxns
# 17   UMPK_copy1  UMPK_copy2  pFBAOpt_Rxns  pFBAOpt_Rxns
# 18         HSST      THRD_L  pFBAOpt_Rxns      ELE_Rxns
# 19          HSK      THRD_L  pFBAOpt_Rxns      ELE_Rxns
# 20        GLU5K       ORNTA  pFBAOpt_Rxns      ELE_Rxns
# 21        HSDxi        HSDy  pFBAOpt_Rxns      ELE_Rxns
# 22       GLCabc         FBP  pFBAOpt_Rxns      MLE_Rxns
# 23       ORNTAC       ACODA  pFBAOpt_Rxns      MLE_Rxns
# 24       ORNTAC        ACGS  pFBAOpt_Rxns      MLE_Rxns
# 25        DMPPS       IPDDI  pFBAOpt_Rxns      ELE_Rxns
# 26        CYTK2       NTPP3  pFBAOpt_Rxns      MLE_Rxns
# 27        CYTK2       NDPK7  pFBAOpt_Rxns      MLE_Rxns
# 28        CTPS1       CTPS2  pFBAOpt_Rxns      MLE_Rxns
# 29         DCPT       DCPT2  pFBAOpt_Rxns  pFBAOpt_Rxns
# 30         DCPT     DCPDPP2  pFBAOpt_Rxns  pFBAOpt_Rxns
# 31         DCPT         ARI  pFBAOpt_Rxns  pFBAOpt_Rxns
# 32         DCPE       DCPT2  pFBAOpt_Rxns  pFBAOpt_Rxns
# 33         DCPE     DCPDPP2  pFBAOpt_Rxns  pFBAOpt_Rxns
# 34         DCPE         ARI  pFBAOpt_Rxns  pFBAOpt_Rxns
# 35       DCPDPP       DCPT2  pFBAOpt_Rxns  pFBAOpt_Rxns
# 36       DCPDPP     DCPDPP2  pFBAOpt_Rxns  pFBAOpt_Rxns
# 37       DCPDPP         ARI  pFBAOpt_Rxns  pFBAOpt_Rxns
# 38         DADK       NTPP5  pFBAOpt_Rxns      MLE_Rxns
# 39         DADK       NDPK8  pFBAOpt_Rxns      MLE_Rxns
# 40        ARGDr       ARGSS  pFBAOpt_Rxns      MLE_Rxns
# 41        ARGDr       ARGSL  pFBAOpt_Rxns      MLE_Rxns
# 42  FACOALPREPH   PREPHACPH  pFBAOpt_Rxns      MLE_Rxns
# 43    FACOAL181     DESAT18  pFBAOpt_Rxns      ELE_Rxns
# 44    FACOAL181   FACOAL180  pFBAOpt_Rxns      ELE_Rxns
# 45       FAS181     DESAT18  pFBAOpt_Rxns      ELE_Rxns
# 46       FAS181   FACOAL180  pFBAOpt_Rxns      ELE_Rxns
# 47       FAS161     DESAT16  pFBAOpt_Rxns      ELE_Rxns
# 48       FAS161   FACOAL161  pFBAOpt_Rxns      ELE_Rxns
# 49      ALATA_L      MMSAD3  pFBAOpt_Rxns      MLE_Rxns
# 50      ALATA_L      ASP1DC  pFBAOpt_Rxns      MLE_Rxns
# 51      ALATA_L       APATr  pFBAOpt_Rxns      MLE_Rxns
# 52        AIRCr       AIRC3  pFBAOpt_Rxns      MLE_Rxns
# 53        AIRCr       AIRC2  pFBAOpt_Rxns      MLE_Rxns
# 54          PGK         PGM  pFBAOpt_Rxns  pFBAOpt_Rxns
# 55          RPE        TALA  pFBAOpt_Rxns  pFBAOpt_Rxns
# 56         TKT2        TALA  pFBAOpt_Rxns  pFBAOpt_Rxns
# 57         TKT2         RPE  pFBAOpt_Rxns  pFBAOpt_Rxns
# 58         TKT1         RPE  pFBAOpt_Rxns  pFBAOpt_Rxns
# 59         TKT1        TKT2  pFBAOpt_Rxns  pFBAOpt_Rxns
# 60       GLUt2r      ICDHyr  pFBAOpt_Rxns  pFBAOpt_Rxns
# 61         HSST        THRS  pFBAOpt_Rxns  pFBAOpt_Rxns
# 62         HSST      SHSL4r  pFBAOpt_Rxns  pFBAOpt_Rxns
# 63          HSK        HSST  pFBAOpt_Rxns  pFBAOpt_Rxns
# 64       GLCabc         PGI  pFBAOpt_Rxns  pFBAOpt_Rxns
# 65         GAPD         PGM  pFBAOpt_Rxns  pFBAOpt_Rxns
# 66         NH4t      GLUt2r  pFBAOpt_Rxns  pFBAOpt_Rxns
# 67          ENO         PGK  pFBAOpt_Rxns  pFBAOpt_Rxns
# 68          ENO        GAPD  pFBAOpt_Rxns  pFBAOpt_Rxns
# 69        DMPPS       IPDPS  pFBAOpt_Rxns  pFBAOpt_Rxns
# 70         GLYK     G3PD1ir  pFBAOpt_Rxns  pFBAOpt_Rxns
# 71          FBA      GLCabc  pFBAOpt_Rxns  pFBAOpt_Rxns
# 72       FAS181   FACOAL181  pFBAOpt_Rxns  pFBAOpt_Rxns
# 73        ACONT      GLUt2r  pFBAOpt_Rxns  pFBAOpt_Rxns
# 74       AICART     AICART2  pFBAOpt_Rxns  pFBAOpt_Rxns

# %%
df = pd.read_csv('iPC815/iPC815_pFBA.csv')
pd.set_option("display.max_rows", None, "display.max_columns", None)
display(df)
# Out:
#           Rxn_1         Rxn_2   Rxn_1_Class   Rxn_2_Class
# 0         GARFT          GART  pFBAOpt_Rxns      ELE_Rxns
# 1         GARFT           PFL  pFBAOpt_Rxns      ELE_Rxns
# 2        GHMT2r          PGCD  pFBAOpt_Rxns      ELE_Rxns
# 3        GHMT2r         PSERT  pFBAOpt_Rxns      ELE_Rxns
# 4        GHMT2r         PSP_L  pFBAOpt_Rxns      ELE_Rxns
# 5       3HAD120        AACPS7  pFBAOpt_Rxns      ELE_Rxns
# 6       3HAD120     FACOAE120  pFBAOpt_Rxns      ELE_Rxns
# 7       3HAD120        ECOAH6  pFBAOpt_Rxns      ELE_Rxns
# 8       3HAD120        HACD6i  pFBAOpt_Rxns      ELE_Rxns
# 9       3HAD120        ACACT9  pFBAOpt_Rxns      ELE_Rxns
# 10      3HAD140        AACPS1  pFBAOpt_Rxns      ELE_Rxns
# 11      3HAD140     FACOAE140  pFBAOpt_Rxns      ELE_Rxns
# 12      3HAD160        AACPS3  pFBAOpt_Rxns      ELE_Rxns
# 13      3HAD160     FACOAE160  pFBAOpt_Rxns      ELE_Rxns
# 14      3OAR120        AACPS7  pFBAOpt_Rxns      ELE_Rxns
# 15      3OAR120     FACOAE120  pFBAOpt_Rxns      ELE_Rxns
# 16      3OAR120        ECOAH6  pFBAOpt_Rxns      ELE_Rxns
# 17      3OAR120        HACD6i  pFBAOpt_Rxns      ELE_Rxns
# 18      3OAR120        ACACT9  pFBAOpt_Rxns      ELE_Rxns
# 19      3OAR160        AACPS3  pFBAOpt_Rxns      ELE_Rxns
# 20      3OAR160     FACOAE160  pFBAOpt_Rxns      ELE_Rxns
# 21      3OAS120        AACPS7  pFBAOpt_Rxns      ELE_Rxns
# 22      3OAS120     FACOAE120  pFBAOpt_Rxns      ELE_Rxns
# 23      3OAS120        ECOAH6  pFBAOpt_Rxns      ELE_Rxns
# 24      3OAS120        HACD6i  pFBAOpt_Rxns      ELE_Rxns
# 25      3OAS120        ACACT9  pFBAOpt_Rxns      ELE_Rxns
# 26      3OAS160        AACPS3  pFBAOpt_Rxns      ELE_Rxns
# 27      3OAS160     FACOAE160  pFBAOpt_Rxns      ELE_Rxns
# 28        ASNS2         ASNS1  pFBAOpt_Rxns      ELE_Rxns
# 29     CYSabcpp          CYSS  pFBAOpt_Rxns      ELE_Rxns
# 30     CYSabcpp         SERAT  pFBAOpt_Rxns      ELE_Rxns
# 31     CYSabcpp          SULR  pFBAOpt_Rxns      ELE_Rxns
# 32     CYSabcpp        SO4tex  pFBAOpt_Rxns      ELE_Rxns
# 33     CYSabcpp      SULabcpp  pFBAOpt_Rxns      ELE_Rxns
# 34     CYSabcpp        PAPSSH  pFBAOpt_Rxns      ELE_Rxns
# 35       CYStex          CYSS  pFBAOpt_Rxns      ELE_Rxns
# 36       CYStex         SERAT  pFBAOpt_Rxns      ELE_Rxns
# 37       CYStex          SULR  pFBAOpt_Rxns      ELE_Rxns
# 38       CYStex        SO4tex  pFBAOpt_Rxns      ELE_Rxns
# 39       CYStex      SULabcpp  pFBAOpt_Rxns      ELE_Rxns
# 40       CYStex        PAPSSH  pFBAOpt_Rxns      ELE_Rxns
# 41       CO2tex          Htex  pFBAOpt_Rxns      ELE_Rxns
# 42       DHORD2        DHORD5  pFBAOpt_Rxns      ELE_Rxns
# 43         FLDR         NDPK8  pFBAOpt_Rxns      ELE_Rxns
# 44        GLU5K          ACGK  pFBAOpt_Rxns      ELE_Rxns
# 45        GLU5K          ACGS  pFBAOpt_Rxns      ELE_Rxns
# 46        GLU5K          AGPR  pFBAOpt_Rxns      ELE_Rxns
# 47        GLUDy         GLUSy  pFBAOpt_Rxns      ELE_Rxns
# 48      FORtppi          GART  pFBAOpt_Rxns      ELE_Rxns
# 49      GLYCtpp       GLYCtex  pFBAOpt_Rxns      ELE_Rxns
# 50        KAS15         KAS14  pFBAOpt_Rxns      ELE_Rxns
# 51     LYSabcpp          ASAD  pFBAOpt_Rxns      ELE_Rxns
# 52     LYSabcpp          ASPK  pFBAOpt_Rxns      ELE_Rxns
# 53     LYSabcpp         DAPDC  pFBAOpt_Rxns      MLE_Rxns
# 54     LYSabcpp          DAPE  pFBAOpt_Rxns      MLE_Rxns
# 55     LYSabcpp        DHDPRy  pFBAOpt_Rxns      MLE_Rxns
# 56     LYSabcpp         DHDPS  pFBAOpt_Rxns      MLE_Rxns
# 57     LYSabcpp         SDPDS  pFBAOpt_Rxns      MLE_Rxns
# 58     LYSabcpp         THDPS  pFBAOpt_Rxns      MLE_Rxns
# 59     LYSabcpp         SDPTA  pFBAOpt_Rxns      MLE_Rxns
# 60       LYStex          ASAD  pFBAOpt_Rxns      ELE_Rxns
# 61       LYStex          ASPK  pFBAOpt_Rxns      ELE_Rxns
# 62       LYStex         DAPDC  pFBAOpt_Rxns      MLE_Rxns
# 63       LYStex          DAPE  pFBAOpt_Rxns      MLE_Rxns
# 64       LYStex        DHDPRy  pFBAOpt_Rxns      MLE_Rxns
# 65       LYStex         DHDPS  pFBAOpt_Rxns      MLE_Rxns
# 66       LYStex         SDPDS  pFBAOpt_Rxns      MLE_Rxns
# 67       LYStex         THDPS  pFBAOpt_Rxns      MLE_Rxns
# 68       LYStex         SDPTA  pFBAOpt_Rxns      MLE_Rxns
# 69          MDH           PPC  pFBAOpt_Rxns      ELE_Rxns
# 70        MTHFC          GART  pFBAOpt_Rxns      ELE_Rxns
# 71        MTHFC           PFL  pFBAOpt_Rxns      ELE_Rxns
# 72        MTHFD          GART  pFBAOpt_Rxns      ELE_Rxns
# 73        MTHFD           PFL  pFBAOpt_Rxns      ELE_Rxns
# 74        NDPK1          ADK3  pFBAOpt_Rxns      ELE_Rxns
# 75        NDPK5        RNTR2c  pFBAOpt_Rxns  pFBAOpt_Rxns
# 76        NDPK7        RNTR3c  pFBAOpt_Rxns  pFBAOpt_Rxns
# 77         G5SD          ACGK  pFBAOpt_Rxns      ELE_Rxns
# 78         G5SD          ACGS  pFBAOpt_Rxns      ELE_Rxns
# 79         G5SD          AGPR  pFBAOpt_Rxns      ELE_Rxns
# 80         P5CR          ACGK  pFBAOpt_Rxns      ELE_Rxns
# 81         P5CR          ACGS  pFBAOpt_Rxns      ELE_Rxns
# 82         P5CR         ACODA  pFBAOpt_Rxns      ELE_Rxns
# 83         P5CR         ACOTA  pFBAOpt_Rxns      ELE_Rxns
# 84         P5CR          AGPR  pFBAOpt_Rxns      ELE_Rxns
# 85   PG140abcpp   PGP140abcpp  pFBAOpt_Rxns      ELE_Rxns
# 86   PG140abcpp     PGPP140pp  pFBAOpt_Rxns      ELE_Rxns
# 87   PG160abcpp   PGP160abcpp  pFBAOpt_Rxns      ELE_Rxns
# 88   PG160abcpp     PGPP160pp  pFBAOpt_Rxns      ELE_Rxns
# 89   PG161abcpp   PGP161abcpp  pFBAOpt_Rxns      ELE_Rxns
# 90   PG161abcpp     PGPP161pp  pFBAOpt_Rxns      ELE_Rxns
# 91   PG181abcpp   PGP181abcpp  pFBAOpt_Rxns      ELE_Rxns
# 92   PG181abcpp     PGPP181pp  pFBAOpt_Rxns      ELE_Rxns
# 93     PNTOt4pp        ASP1DC  pFBAOpt_Rxns      MLE_Rxns
# 94     PNTOt4pp           DPR  pFBAOpt_Rxns      MLE_Rxns
# 95     PNTOt4pp         MOHMT  pFBAOpt_Rxns      MLE_Rxns
# 96     PNTOt4pp         PANTS  pFBAOpt_Rxns      MLE_Rxns
# 97      PNTOtex        ASP1DC  pFBAOpt_Rxns      MLE_Rxns
# 98      PNTOtex           DPR  pFBAOpt_Rxns      MLE_Rxns
# 99      PNTOtex         MOHMT  pFBAOpt_Rxns      MLE_Rxns
# 100     PNTOtex         PANTS  pFBAOpt_Rxns      MLE_Rxns
# 101         PPK           PPA  pFBAOpt_Rxns      ELE_Rxns
# 102     PGPP140   PGP140abcpp  pFBAOpt_Rxns      ELE_Rxns
# 103     PGPP140     PGPP140pp  pFBAOpt_Rxns      ELE_Rxns
# 104      RNTR1c         NDPK8  pFBAOpt_Rxns      ELE_Rxns
# 105     PGPP160   PGP160abcpp  pFBAOpt_Rxns      ELE_Rxns
# 106     PGPP160     PGPP160pp  pFBAOpt_Rxns      ELE_Rxns
# 107     PGPP161   PGP161abcpp  pFBAOpt_Rxns      ELE_Rxns
# 108     PGPP161     PGPP161pp  pFBAOpt_Rxns      ELE_Rxns
# 109     PGPP181   PGP181abcpp  pFBAOpt_Rxns      ELE_Rxns
# 110     PGPP181     PGPP181pp  pFBAOpt_Rxns      ELE_Rxns
# 111        THRA          ASAD  pFBAOpt_Rxns      ELE_Rxns
# 112        THRA          ASPK  pFBAOpt_Rxns      ELE_Rxns
# 113        THRA          HSDy  pFBAOpt_Rxns      ELE_Rxns
# 114        THRA           HSK  pFBAOpt_Rxns      ELE_Rxns
# 115        THRA          THRS  pFBAOpt_Rxns      ELE_Rxns
# 116       SUCDi       SUCCtex  pFBAOpt_Rxns      ELE_Rxns
# 117    TYRt2rpp         CHORM  pFBAOpt_Rxns      MLE_Rxns
# 118    TYRt2rpp          PPND  pFBAOpt_Rxns      MLE_Rxns
# 119    TYRt2rpp         TYRTA  pFBAOpt_Rxns      MLE_Rxns
# 120      TYRtex         CHORM  pFBAOpt_Rxns      MLE_Rxns
# 121      TYRtex          PPND  pFBAOpt_Rxns      MLE_Rxns
# 122      TYRtex         TYRTA  pFBAOpt_Rxns      MLE_Rxns
# 123       TRPS1         TRPS2  pFBAOpt_Rxns      ELE_Rxns
# 124       TRPS1         TRPS3  pFBAOpt_Rxns      ELE_Rxns
# 125       NADS1         NADS2  pFBAOpt_Rxns      ELE_Rxns
# 126     PIt2rpp      PIuabcpp  pFBAOpt_Rxns      ELE_Rxns
# 127       ENOPH   23DK5MPPISO  pFBAOpt_Rxns      ELE_Rxns
# 128       ENOPH  2OH3K5MPPISO  pFBAOpt_Rxns      ELE_Rxns
# 129      EAR40x        EAR40y  pFBAOpt_Rxns      ELE_Rxns
# 130      EAR60x        EAR60y  pFBAOpt_Rxns      ELE_Rxns
# 131      EAR80x        EAR80y  pFBAOpt_Rxns      ELE_Rxns
# 132     EAR121x       EAR121y  pFBAOpt_Rxns      ELE_Rxns
# 133     EAR141x       EAR141y  pFBAOpt_Rxns      ELE_Rxns
# 134     EAR161x       EAR161y  pFBAOpt_Rxns      ELE_Rxns
# 135     EAR181x       EAR181y  pFBAOpt_Rxns      ELE_Rxns
# 136        ADK1          ADK3  pFBAOpt_Rxns      ELE_Rxns
# 137      G5SADs          ACGK  pFBAOpt_Rxns      ELE_Rxns
# 138      G5SADs          ACGS  pFBAOpt_Rxns      ELE_Rxns
# 139      G5SADs         ACODA  pFBAOpt_Rxns      ELE_Rxns
# 140      G5SADs         ACOTA  pFBAOpt_Rxns      ELE_Rxns
# 141      G5SADs          AGPR  pFBAOpt_Rxns      ELE_Rxns
# 142       ORNCD          ACGK  pFBAOpt_Rxns      ELE_Rxns
# 143       ORNCD          ACGS  pFBAOpt_Rxns      ELE_Rxns
# 144       ORNCD         ACODA  pFBAOpt_Rxns      ELE_Rxns
# 145       ORNCD         ACOTA  pFBAOpt_Rxns      ELE_Rxns
# 146       ORNCD          AGPR  pFBAOpt_Rxns      ELE_Rxns
# 147    CYSabcpp        GHMT2r  pFBAOpt_Rxns  pFBAOpt_Rxns
# 148       CYSDS        GHMT2r  pFBAOpt_Rxns  pFBAOpt_Rxns
# 149      CYStex        GHMT2r  pFBAOpt_Rxns  pFBAOpt_Rxns
# 150     CITt7pp            CS  pFBAOpt_Rxns  pFBAOpt_Rxns
# 151      CITtex            CS  pFBAOpt_Rxns  pFBAOpt_Rxns
# 152      CO2tex          GAPD  pFBAOpt_Rxns  pFBAOpt_Rxns
# 153      CO2tex      ATPS4rpp  pFBAOpt_Rxns  pFBAOpt_Rxns
# 154     H2St1pp        GHMT2r  pFBAOpt_Rxns  pFBAOpt_Rxns
# 155      H2Stex        GHMT2r  pFBAOpt_Rxns  pFBAOpt_Rxns
# 156     GLYt2pp      CYSabcpp  pFBAOpt_Rxns  pFBAOpt_Rxns
# 157     GLYt2pp         CYSDS  pFBAOpt_Rxns  pFBAOpt_Rxns
# 158     GLYt2pp        CYStex  pFBAOpt_Rxns  pFBAOpt_Rxns
# 159     GLYt2pp       H2St1pp  pFBAOpt_Rxns  pFBAOpt_Rxns
# 160     GLYt2pp        H2Stex  pFBAOpt_Rxns  pFBAOpt_Rxns
# 161      GLYtex      CYSabcpp  pFBAOpt_Rxns  pFBAOpt_Rxns
# 162      GLYtex         CYSDS  pFBAOpt_Rxns  pFBAOpt_Rxns
# 163      GLYtex        CYStex  pFBAOpt_Rxns  pFBAOpt_Rxns
# 164      GLYtex       H2St1pp  pFBAOpt_Rxns  pFBAOpt_Rxns
# 165      GLYtex        H2Stex  pFBAOpt_Rxns  pFBAOpt_Rxns
# 166       MTHFC         GARFT  pFBAOpt_Rxns  pFBAOpt_Rxns
# 167       MTHFD         GARFT  pFBAOpt_Rxns  pFBAOpt_Rxns
# 168       NDPK5          FLDR  pFBAOpt_Rxns  pFBAOpt_Rxns
# 169       NDPK7          FLDR  pFBAOpt_Rxns  pFBAOpt_Rxns
# 170         PGK        CO2tex  pFBAOpt_Rxns  pFBAOpt_Rxns
# 171         RPE           GND  pFBAOpt_Rxns  pFBAOpt_Rxns
# 172         RPE       G6PDH2r  pFBAOpt_Rxns  pFBAOpt_Rxns
# 173         RPE           PGL  pFBAOpt_Rxns  pFBAOpt_Rxns
# 174        TALA           RPE  pFBAOpt_Rxns  pFBAOpt_Rxns
# 175      SUCOAS         AKGDH  pFBAOpt_Rxns  pFBAOpt_Rxns
# 176        TKT1           RPE  pFBAOpt_Rxns  pFBAOpt_Rxns
# 177        TKT1          TALA  pFBAOpt_Rxns  pFBAOpt_Rxns
# 178        TKT2           GND  pFBAOpt_Rxns  pFBAOpt_Rxns
# 179        TKT2       G6PDH2r  pFBAOpt_Rxns  pFBAOpt_Rxns
# 180        TKT2           PGL  pFBAOpt_Rxns  pFBAOpt_Rxns
# 181        TKT2           RPE  pFBAOpt_Rxns  pFBAOpt_Rxns
# 182        TKT2          TALA  pFBAOpt_Rxns  pFBAOpt_Rxns
# 183        TKT2          TKT1  pFBAOpt_Rxns  pFBAOpt_Rxns
# 184         TPI           FBA  pFBAOpt_Rxns  pFBAOpt_Rxns
# 185         TPI           PFK  pFBAOpt_Rxns  pFBAOpt_Rxns
# 186        ADK1         NDPK1  pFBAOpt_Rxns  pFBAOpt_Rxns
# 187       ORNCD          P5CR  pFBAOpt_Rxns  pFBAOpt_Rxns
# 188       ORNCD        G5SADs  pFBAOpt_Rxns  pFBAOpt_Rxns

# %%
df = pd.read_csv('iYL1228/iYL1228_pFBA.csv')
pd.set_option("display.max_rows", None, "display.max_columns", None)
display(df)
# Out:
#             Rxn_1          Rxn_2   Rxn_1_Class   Rxn_2_Class
# 0         3OAS120         AACPS7  pFBAOpt_Rxns      MLE_Rxns
# 1         3OAS120      FACOAE120  pFBAOpt_Rxns      MLE_Rxns
# 2         3OAS120         ECOAH6  pFBAOpt_Rxns      MLE_Rxns
# 3         3OAS120         HACD6i  pFBAOpt_Rxns      MLE_Rxns
# 4         3OAS120         ACACT9  pFBAOpt_Rxns      MLE_Rxns
# 5         3OAS160         AACPS3  pFBAOpt_Rxns      MLE_Rxns
# 6         3OAS160      FACOAE160  pFBAOpt_Rxns      MLE_Rxns
# 7         3HAD120         AACPS7  pFBAOpt_Rxns      MLE_Rxns
# 8         3HAD120      FACOAE120  pFBAOpt_Rxns      MLE_Rxns
# 9         3HAD120         ECOAH6  pFBAOpt_Rxns      MLE_Rxns
# 10        3HAD120         HACD6i  pFBAOpt_Rxns      MLE_Rxns
# 11        3HAD120         ACACT9  pFBAOpt_Rxns      MLE_Rxns
# 12        3HAD140      FACOAE140  pFBAOpt_Rxns      MLE_Rxns
# 13        3HAD160         AACPS3  pFBAOpt_Rxns      MLE_Rxns
# 14        3HAD160      FACOAE160  pFBAOpt_Rxns      MLE_Rxns
# 15          ACHBS         ACLS_a  pFBAOpt_Rxns      ELE_Rxns
# 16          ACHBS           ilvg  pFBAOpt_Rxns      ELE_Rxns
# 17        3OAR120         AACPS7  pFBAOpt_Rxns      MLE_Rxns
# 18        3OAR120      FACOAE120  pFBAOpt_Rxns      MLE_Rxns
# 19        3OAR120         ECOAH6  pFBAOpt_Rxns      MLE_Rxns
# 20        3OAR120         HACD6i  pFBAOpt_Rxns      MLE_Rxns
# 21        3OAR120         ACACT9  pFBAOpt_Rxns      MLE_Rxns
# 22        3OAR160         AACPS3  pFBAOpt_Rxns      MLE_Rxns
# 23        3OAR160      FACOAE160  pFBAOpt_Rxns      MLE_Rxns
# 24         ACONTa           FGLU  pFBAOpt_Rxns      MLE_Rxns
# 25         ACONTa         FORAMD  pFBAOpt_Rxns      MLE_Rxns
# 26         ACONTa          HISDr  pFBAOpt_Rxns      MLE_Rxns
# 27         ACONTa           IZPN  pFBAOpt_Rxns      MLE_Rxns
# 28         ACONTa           URCN  pFBAOpt_Rxns      MLE_Rxns
# 29         ACONTb           FGLU  pFBAOpt_Rxns      MLE_Rxns
# 30         ACONTb         FORAMD  pFBAOpt_Rxns      MLE_Rxns
# 31         ACONTb          HISDr  pFBAOpt_Rxns      MLE_Rxns
# 32         ACONTb           IZPN  pFBAOpt_Rxns      MLE_Rxns
# 33         ACONTb           URCN  pFBAOpt_Rxns      MLE_Rxns
# 34          ASNS2          ASNS1  pFBAOpt_Rxns      MLE_Rxns
# 35             CS           FGLU  pFBAOpt_Rxns      MLE_Rxns
# 36             CS         FORAMD  pFBAOpt_Rxns      MLE_Rxns
# 37             CS          HISDr  pFBAOpt_Rxns      MLE_Rxns
# 38             CS           IZPN  pFBAOpt_Rxns      MLE_Rxns
# 39             CS           URCN  pFBAOpt_Rxns      MLE_Rxns
# 40         CYSTGL         THRD_L  pFBAOpt_Rxns      ELE_Rxns
# 41            CYS           CYSS  pFBAOpt_Rxns      MLE_Rxns
# 42            CYS          SERAT  pFBAOpt_Rxns      MLE_Rxns
# 43          CYTK1           NTD4  pFBAOpt_Rxns      MLE_Rxns
# 44       DALAt2pp        DALAtex  pFBAOpt_Rxns      MLE_Rxns
# 45         DHORD2         DHORD5  pFBAOpt_Rxns      ELE_Rxns
# 46       DNAMTn2r           METS  pFBAOpt_Rxns      MLE_Rxns
# 47       DNAMTn2r         MTHFR2  pFBAOpt_Rxns      MLE_Rxns
# 48        EAR121y        EAR121x  pFBAOpt_Rxns  pFBAOpt_Rxns
# 49        EAR141y        EAR141x  pFBAOpt_Rxns  pFBAOpt_Rxns
# 50        EAR161x        EAR161y  pFBAOpt_Rxns  pFBAOpt_Rxns
# 51        EAR181y        EAR181x  pFBAOpt_Rxns  pFBAOpt_Rxns
# 52         EAR40x         EAR40y  pFBAOpt_Rxns  pFBAOpt_Rxns
# 53         EAR60x         EAR60y  pFBAOpt_Rxns  pFBAOpt_Rxns
# 54         EAR80y         EAR80x  pFBAOpt_Rxns  pFBAOpt_Rxns
# 55            FUM       SUCCt3pp  pFBAOpt_Rxns      MLE_Rxns
# 56          GARFT           GART  pFBAOpt_Rxns      MLE_Rxns
# 57           G5SD         NACODA  pFBAOpt_Rxns      MLE_Rxns
# 58   GLCtex_copy2   GLCtex_copy1  pFBAOpt_Rxns  pFBAOpt_Rxns
# 59          GLU5K         NACODA  pFBAOpt_Rxns      MLE_Rxns
# 60        GLYCtpp        GLYCtex  pFBAOpt_Rxns      MLE_Rxns
# 61           FLDR          NDPK7  pFBAOpt_Rxns  pFBAOpt_Rxns
# 62           FLDR          NDPK8  pFBAOpt_Rxns      ELE_Rxns
# 63         HCYSMT           METS  pFBAOpt_Rxns      MLE_Rxns
# 64         HCYSMT         MTHFR2  pFBAOpt_Rxns      MLE_Rxns
# 65         ICDHyr           FGLU  pFBAOpt_Rxns      MLE_Rxns
# 66         ICDHyr         FORAMD  pFBAOpt_Rxns      MLE_Rxns
# 67         ICDHyr          HISDr  pFBAOpt_Rxns      MLE_Rxns
# 68         ICDHyr           IZPN  pFBAOpt_Rxns      MLE_Rxns
# 69         ICDHyr           URCN  pFBAOpt_Rxns      MLE_Rxns
# 70          KAS15          KAS14  pFBAOpt_Rxns      ELE_Rxns
# 71          NDPK1           ADK3  pFBAOpt_Rxns      ELE_Rxns
# 72          NDPK5         RNTR2c  pFBAOpt_Rxns  pFBAOpt_Rxns
# 73          MTHFC           GART  pFBAOpt_Rxns      MLE_Rxns
# 74          MTHFC            PFL  pFBAOpt_Rxns      MLE_Rxns
# 75          MTHFD           GART  pFBAOpt_Rxns      MLE_Rxns
# 76          MTHFD            PFL  pFBAOpt_Rxns      MLE_Rxns
# 77          PAPSR           GRXR  pFBAOpt_Rxns      ELE_Rxns
# 78          PAPSR          GTHOr  pFBAOpt_Rxns      ELE_Rxns
# 79          PAPSR         PAPSR2  pFBAOpt_Rxns      ELE_Rxns
# 80        PGPP181   2AGPG181tipp  pFBAOpt_Rxns      MLE_Rxns
# 81        PGPP181     2AGPGAT181  pFBAOpt_Rxns      MLE_Rxns
# 82        PGPP181  FACOAL181t2pp  pFBAOpt_Rxns      MLE_Rxns
# 83        PGPP181      PGPP181pp  pFBAOpt_Rxns      MLE_Rxns
# 84        PGPP181    PGP181abcpp  pFBAOpt_Rxns      MLE_Rxns
# 85        PGPP181   PLIPA1G181pp  pFBAOpt_Rxns      MLE_Rxns
# 86     PG160abcpp    PGP160abcpp  pFBAOpt_Rxns      MLE_Rxns
# 87     PG160abcpp      PGPP160pp  pFBAOpt_Rxns      MLE_Rxns
# 88     PG161abcpp    PGP161abcpp  pFBAOpt_Rxns      MLE_Rxns
# 89     PG161abcpp      PGPP161pp  pFBAOpt_Rxns      MLE_Rxns
# 90     PG181abcpp      PGPP181pp  pFBAOpt_Rxns      MLE_Rxns
# 91     PG181abcpp    PGP181abcpp  pFBAOpt_Rxns      MLE_Rxns
# 92        PIt2rpp       PIuabcpp  pFBAOpt_Rxns      MLE_Rxns
# 93        PGPP160   2AGPG160tipp  pFBAOpt_Rxns      MLE_Rxns
# 94        PGPP160     2AGPGAT160  pFBAOpt_Rxns      MLE_Rxns
# 95        PGPP160  FACOAL160t2pp  pFBAOpt_Rxns      MLE_Rxns
# 96        PGPP160    PGP160abcpp  pFBAOpt_Rxns      MLE_Rxns
# 97        PGPP160   PLIPA1G160pp  pFBAOpt_Rxns      MLE_Rxns
# 98        PGPP160      PGPP160pp  pFBAOpt_Rxns      MLE_Rxns
# 99        PGPP161   2AGPG161tipp  pFBAOpt_Rxns      MLE_Rxns
# 100       PGPP161     2AGPGAT161  pFBAOpt_Rxns      MLE_Rxns
# 101       PGPP161  FACOAL161t2pp  pFBAOpt_Rxns      MLE_Rxns
# 102       PGPP161    PGP161abcpp  pFBAOpt_Rxns      MLE_Rxns
# 103       PGPP161   PLIPA1G161pp  pFBAOpt_Rxns      MLE_Rxns
# 104       PGPP161      PGPP161pp  pFBAOpt_Rxns      MLE_Rxns
# 105        RNTR1c          NDPK8  pFBAOpt_Rxns      ELE_Rxns
# 106        RNTR3c          NDPK7  pFBAOpt_Rxns  pFBAOpt_Rxns
# 107           RPI         KDOCT2  pFBAOpt_Rxns      MLE_Rxns
# 108           RPI           MOAT  pFBAOpt_Rxns      MLE_Rxns
# 109           RPI          MOAT2  pFBAOpt_Rxns      MLE_Rxns
# 110           PPK            PPA  pFBAOpt_Rxns      MLE_Rxns
# 111          TRDR           GRXR  pFBAOpt_Rxns      ELE_Rxns
# 112          TRDR          GTHOr  pFBAOpt_Rxns      ELE_Rxns
# 113          TRDR         PAPSR2  pFBAOpt_Rxns      ELE_Rxns
# 114         TRPS1          TRPS2  pFBAOpt_Rxns      ELE_Rxns
# 115         TRPS1          TRPS3  pFBAOpt_Rxns      ELE_Rxns
# 116         VALTA         VPAMTr  pFBAOpt_Rxns      ELE_Rxns
# 117         PRPPS         R15BPK  pFBAOpt_Rxns      ELE_Rxns
# 118         PRPPS           R1PK  pFBAOpt_Rxns      ELE_Rxns
# 119         PRPPS            PPM  pFBAOpt_Rxns      ELE_Rxns
# 120         NDPK5           FLDR  pFBAOpt_Rxns  pFBAOpt_Rxns
# 121         MTHFC          GARFT  pFBAOpt_Rxns  pFBAOpt_Rxns
# 122         MTHFD          GARFT  pFBAOpt_Rxns  pFBAOpt_Rxns
# 123         O2tex           GAPD  pFBAOpt_Rxns  pFBAOpt_Rxns
# 124         O2tpp           GAPD  pFBAOpt_Rxns  pFBAOpt_Rxns
# 125          PGCD         GHMT2r  pFBAOpt_Rxns  pFBAOpt_Rxns
# 126           PGK          O2tex  pFBAOpt_Rxns  pFBAOpt_Rxns
# 127           PGK          O2tpp  pFBAOpt_Rxns  pFBAOpt_Rxns
# 128         PSERT         GHMT2r  pFBAOpt_Rxns  pFBAOpt_Rxns
# 129         PSP_L         GHMT2r  pFBAOpt_Rxns  pFBAOpt_Rxns
# 130           PPC            FUM  pFBAOpt_Rxns  pFBAOpt_Rxns
# 131           RPE            GND  pFBAOpt_Rxns      MLE_Rxns
# 132           RPI            RPE  pFBAOpt_Rxns  pFBAOpt_Rxns
# 133        SUCOAS          AKGDH  pFBAOpt_Rxns  pFBAOpt_Rxns
# 134          TALA            RPE  pFBAOpt_Rxns  pFBAOpt_Rxns
# 135          TALA            RPI  pFBAOpt_Rxns  pFBAOpt_Rxns
# 136          TKT1            RPE  pFBAOpt_Rxns  pFBAOpt_Rxns
# 137          TKT1            RPI  pFBAOpt_Rxns  pFBAOpt_Rxns
# 138          TKT1           TALA  pFBAOpt_Rxns  pFBAOpt_Rxns
# 139          TKT2            GND  pFBAOpt_Rxns      MLE_Rxns
# 140          TKT2            RPE  pFBAOpt_Rxns  pFBAOpt_Rxns
# 141          TKT2            RPI  pFBAOpt_Rxns  pFBAOpt_Rxns
# 142          TKT2           TALA  pFBAOpt_Rxns  pFBAOpt_Rxns
# 143          TKT2           TKT1  pFBAOpt_Rxns  pFBAOpt_Rxns

# %%
df = pd.read_csv('STM_v1_0/STM_v1_0_pFBA.csv')
pd.set_option("display.max_rows", None, "display.max_columns", None)
display(df)
# Out:
#             Rxn_1          Rxn_2   Rxn_1_Class   Rxn_2_Class
# 0         3HAD180        ACOAD8f      ELE_Rxns      ELE_Rxns
# 1         3HAD180         AACPS6      ELE_Rxns      ELE_Rxns
# 2         3HAD180      FACOAE180      ELE_Rxns      ELE_Rxns
# 3         3HAD180  FACOAL181t2pp      ELE_Rxns      ELE_Rxns
# 4         3HAD180       CTECOAI8      ELE_Rxns      ELE_Rxns
# 5         3OAR120         AACPS7      ELE_Rxns      ELE_Rxns
# 6         3OAR120         ECOAH6      ELE_Rxns      ELE_Rxns
# 7         3OAR120      FACOAE120      ELE_Rxns      ELE_Rxns
# 8         3OAR120         HACD6i      ELE_Rxns      ELE_Rxns
# 9         3OAR120         ACACT9      ELE_Rxns      ELE_Rxns
# 10        3OAR160         AACPS3      ELE_Rxns      ELE_Rxns
# 11        3OAR160      FACOAE160      ELE_Rxns      ELE_Rxns
# 12        3OAR180        ACOAD8f      ELE_Rxns      ELE_Rxns
# 13        3OAR180         AACPS6      ELE_Rxns      ELE_Rxns
# 14        3OAR180      FACOAE180      ELE_Rxns      ELE_Rxns
# 15        3OAR180  FACOAL181t2pp      ELE_Rxns      ELE_Rxns
# 16        3OAR180       CTECOAI8      ELE_Rxns      ELE_Rxns
# 17        3OAS120         AACPS7      ELE_Rxns      ELE_Rxns
# 18        3OAS120         ECOAH6      ELE_Rxns      ELE_Rxns
# 19        3OAS120      FACOAE120      ELE_Rxns      ELE_Rxns
# 20        3OAS120         HACD6i      ELE_Rxns      ELE_Rxns
# 21        3OAS120         ACACT9      ELE_Rxns      ELE_Rxns
# 22        3OAS160         AACPS3      ELE_Rxns      ELE_Rxns
# 23        3OAS160      FACOAE160      ELE_Rxns      ELE_Rxns
# 24        3OAS180        ACOAD8f      ELE_Rxns      ELE_Rxns
# 25        3OAS180         AACPS6      ELE_Rxns      ELE_Rxns
# 26        3OAS180      FACOAE180      ELE_Rxns      ELE_Rxns
# 27        3OAS180  FACOAL181t2pp      ELE_Rxns      ELE_Rxns
# 28        3OAS180       CTECOAI8      ELE_Rxns      ELE_Rxns
# 29        3HAD120         AACPS7      ELE_Rxns      ELE_Rxns
# 30        3HAD120         ECOAH6      ELE_Rxns      ELE_Rxns
# 31        3HAD120      FACOAE120      ELE_Rxns      ELE_Rxns
# 32        3HAD120         HACD6i      ELE_Rxns      ELE_Rxns
# 33        3HAD120         ACACT9      ELE_Rxns      ELE_Rxns
# 34        3HAD140         AACPS1      ELE_Rxns      ELE_Rxns
# 35        3HAD140      FACOAE140      ELE_Rxns      ELE_Rxns
# 36        3HAD160         AACPS3      ELE_Rxns      ELE_Rxns
# 37        3HAD160      FACOAE160      ELE_Rxns      ELE_Rxns
# 38           ADK1           ADK3      ELE_Rxns      ELE_Rxns
# 39          ASNS2          ASNS1      ELE_Rxns      ELE_Rxns
# 40         DHORD2         DHORD5      ELE_Rxns      ELE_Rxns
# 41        EAR121x        EAR121y      ELE_Rxns      ELE_Rxns
# 42        EAR141x        EAR141y      ELE_Rxns      ELE_Rxns
# 43        DKMPPD3         DKMPPD      MLE_Rxns      MLE_Rxns
# 44        EAR161x        EAR161y      ELE_Rxns      ELE_Rxns
# 45        EAR181x        EAR181y      ELE_Rxns      ELE_Rxns
# 46         EAR40x         EAR40y      ELE_Rxns      ELE_Rxns
# 47         EAR60x         EAR60y      ELE_Rxns      ELE_Rxns
# 48         EAR80x         EAR80y      ELE_Rxns      ELE_Rxns
# 49        FORtppi           GART      ELE_Rxns      ELE_Rxns
# 50           G5SD         NACODA      ELE_Rxns      ELE_Rxns
# 51            FUM       SUCCt3pp  pFBAOpt_Rxns      ELE_Rxns
# 52          GARFT           GART      ELE_Rxns      ELE_Rxns
# 53   GLCtex_copy1   GLCtex_copy2  pFBAOpt_Rxns  pFBAOpt_Rxns
# 54        GLYCtpp        GLYCtex      ELE_Rxns      ELE_Rxns
# 55          GLU5K         NACODA      ELE_Rxns      ELE_Rxns
# 56          GLUDy          GLUSy      ELE_Rxns      ELE_Rxns
# 57          KAS15          KAS14      ELE_Rxns      ELE_Rxns
# 58          Kt2pp         Kabcpp      ELE_Rxns      ELE_Rxns
# 59          NDPK1           ADK3      ELE_Rxns      ELE_Rxns
# 60          MTHFC           GART      ELE_Rxns      ELE_Rxns
# 61          MTHFD           GART      ELE_Rxns      ELE_Rxns
# 62          ORNDC           AGMT      ELE_Rxns      ELE_Rxns
# 63          ORNDC        UREAtex      ELE_Rxns      ELE_Rxns
# 64          ORNDC        UREAtpp      ELE_Rxns      ELE_Rxns
# 65     PA140abcpp     CLPNH140pp      ELE_Rxns      ELE_Rxns
# 66     PA160abcpp     CLPNH160pp      ELE_Rxns      ELE_Rxns
# 67     PA161abcpp     CLPNH161pp      ELE_Rxns      ELE_Rxns
# 68     PA180abcpp     CLPNH180pp      ELE_Rxns      ELE_Rxns
# 69     PA181abcpp     CLPNH181pp      ELE_Rxns      ELE_Rxns
# 70          O2tex         DHORD5  pFBAOpt_Rxns      ELE_Rxns
# 71          O2tex           FRD2  pFBAOpt_Rxns      ELE_Rxns
# 72          O2tex       SUCCt3pp  pFBAOpt_Rxns      ELE_Rxns
# 73          O2tex        SUCCtex  pFBAOpt_Rxns      ELE_Rxns
# 74          O2tpp         DHORD5  pFBAOpt_Rxns      ELE_Rxns
# 75          O2tpp           FRD2  pFBAOpt_Rxns      ELE_Rxns
# 76          O2tpp       SUCCt3pp  pFBAOpt_Rxns      ELE_Rxns
# 77          O2tpp        SUCCtex  pFBAOpt_Rxns      ELE_Rxns
# 78      PAPA161pp      ENLIPAtex      ELE_Rxns      ELE_Rxns
# 79      PAPA161pp      LIPAabcpp      ELE_Rxns      ELE_Rxns
# 80      PAPA161pp     PETNT161pp      ELE_Rxns      ELE_Rxns
# 81      PAPA181pp      ENLIPAtex      ELE_Rxns      ELE_Rxns
# 82      PAPA181pp      LIPAabcpp      ELE_Rxns      ELE_Rxns
# 83      PAPA181pp     PETNT181pp      ELE_Rxns      ELE_Rxns
# 84          PAPSR          GTHOr      ELE_Rxns      ELE_Rxns
# 85          PAPSR           GRXR      ELE_Rxns      ELE_Rxns
# 86          PAPSR         PAPSR2      ELE_Rxns      ELE_Rxns
# 87     PG140abcpp    PGP140abcpp      ELE_Rxns      ELE_Rxns
# 88     PG140abcpp      PGPP140pp      ELE_Rxns      ELE_Rxns
# 89     PG160abcpp    PGP160abcpp      ELE_Rxns      ELE_Rxns
# 90     PG160abcpp      PGPP160pp      ELE_Rxns      ELE_Rxns
# 91     PG161abcpp    PGP161abcpp      ELE_Rxns      ELE_Rxns
# 92     PG161abcpp      PGPP161pp      ELE_Rxns      ELE_Rxns
# 93     PG180abcpp    PGP180abcpp      ELE_Rxns      ELE_Rxns
# 94     PG180abcpp      PGPP180pp      ELE_Rxns      ELE_Rxns
# 95     PG181abcpp    PGP181abcpp      ELE_Rxns      ELE_Rxns
# 96     PG181abcpp      PGPP181pp      ELE_Rxns      ELE_Rxns
# 97        PGPP140    PGP140abcpp      ELE_Rxns      ELE_Rxns
# 98        PGPP140      PGPP140pp      ELE_Rxns      ELE_Rxns
# 99        PGPP160    PGP160abcpp      ELE_Rxns      ELE_Rxns
# 100       PGPP160      PGPP160pp      ELE_Rxns      ELE_Rxns
# 101       PGPP161    PGP161abcpp      ELE_Rxns      ELE_Rxns
# 102       PGPP161      PGPP161pp      ELE_Rxns      ELE_Rxns
# 103       PGPP180    PGP180abcpp      ELE_Rxns      ELE_Rxns
# 104       PGPP180      PGPP180pp      ELE_Rxns      ELE_Rxns
# 105       PGPP181    PGP181abcpp      ELE_Rxns      ELE_Rxns
# 106       PGPP181      PGPP181pp      ELE_Rxns      ELE_Rxns
# 107       PIt2rpp       PIuabcpp      ELE_Rxns      ELE_Rxns
# 108           PPC            ICL      ELE_Rxns      ELE_Rxns
# 109        RNTR1c          NDPK8      ELE_Rxns      ELE_Rxns
# 110        RNTR2c          NDPK5      ELE_Rxns      ELE_Rxns
# 111        RNTR3c          NDPK7      ELE_Rxns      ELE_Rxns
# 112          TRDR          GTHOr      ELE_Rxns      ELE_Rxns
# 113          TRDR           GRXR      ELE_Rxns      ELE_Rxns
# 114          TRDR         PAPSR2      ELE_Rxns      ELE_Rxns
# 115         TRPS1          TRPS2      ELE_Rxns      ELE_Rxns
# 116         TRPS1          TRPS3      ELE_Rxns      ELE_Rxns
# 117         VALTA         VPAMTr      ELE_Rxns      ELE_Rxns
# 118        ZN2tpp        ZNabcpp      ELE_Rxns      ELE_Rxns
# 119         CBMKr           CBPS      ELE_Rxns      ELE_Rxns
# 120          SO3R           SULR      ELE_Rxns      ELE_Rxns
# 121       OA5L_ST       OA5VL_ST      ELE_Rxns      ELE_Rxns
# 122          GAPD       ATPS4rpp  pFBAOpt_Rxns  pFBAOpt_Rxns
# 123         NDPK1           ADK1      ELE_Rxns      ELE_Rxns
# 124         MTHFC          GARFT      ELE_Rxns      ELE_Rxns
# 125         MTHFD          GARFT      ELE_Rxns      ELE_Rxns
# 126         O2tex        DKMPPD3  pFBAOpt_Rxns      MLE_Rxns
# 127         O2tex            ENO  pFBAOpt_Rxns  pFBAOpt_Rxns
# 128         O2tex            FBA  pFBAOpt_Rxns  pFBAOpt_Rxns
# 129         O2tex           GAPD  pFBAOpt_Rxns  pFBAOpt_Rxns
# 130         O2tpp        DKMPPD3  pFBAOpt_Rxns      MLE_Rxns
# 131         O2tpp            ENO  pFBAOpt_Rxns  pFBAOpt_Rxns
# 132         O2tpp            FBA  pFBAOpt_Rxns  pFBAOpt_Rxns
# 133         O2tpp           GAPD  pFBAOpt_Rxns  pFBAOpt_Rxns
# 134          PGCD         GHMT2r      ELE_Rxns      ELE_Rxns
# 135           PFK          O2tex  pFBAOpt_Rxns  pFBAOpt_Rxns
# 136           PFK          O2tpp  pFBAOpt_Rxns  pFBAOpt_Rxns
# 137           PGK       ATPS4rpp  pFBAOpt_Rxns  pFBAOpt_Rxns
# 138           PGK          O2tex  pFBAOpt_Rxns  pFBAOpt_Rxns
# 139           PGK          O2tpp  pFBAOpt_Rxns  pFBAOpt_Rxns
# 140           PGM          O2tex  pFBAOpt_Rxns  pFBAOpt_Rxns
# 141           PGM          O2tpp  pFBAOpt_Rxns  pFBAOpt_Rxns
# 142           PPC            FUM      ELE_Rxns  pFBAOpt_Rxns
# 143           PPC            MDH      ELE_Rxns  pFBAOpt_Rxns
# 144           PPC          O2tex      ELE_Rxns  pFBAOpt_Rxns
# 145           PPC          O2tpp      ELE_Rxns  pFBAOpt_Rxns
# 146           PPC           MALS      ELE_Rxns      ELE_Rxns
# 147         PSERT         GHMT2r      ELE_Rxns      ELE_Rxns
# 148         PSP_L         GHMT2r      ELE_Rxns      ELE_Rxns
# 149           RPE            GND      ELE_Rxns      ELE_Rxns
# 150           RPI            RPE      ELE_Rxns      ELE_Rxns
# 151          TKT1            RPE      ELE_Rxns      ELE_Rxns
# 152          TKT1            RPI      ELE_Rxns      ELE_Rxns
# 153          TKT2            GND      ELE_Rxns      ELE_Rxns
# 154          TKT2            RPE      ELE_Rxns      ELE_Rxns
# 155          TKT2            RPI      ELE_Rxns      ELE_Rxns
# 156          TKT2           TKT1      ELE_Rxns      ELE_Rxns
# 157           TPI            FBA  pFBAOpt_Rxns  pFBAOpt_Rxns
# 158           TPI          O2tex  pFBAOpt_Rxns  pFBAOpt_Rxns
# 159           TPI          O2tpp  pFBAOpt_Rxns  pFBAOpt_Rxns
# 160           TPI            PFK  pFBAOpt_Rxns  pFBAOpt_Rxns
# 161         SUCDi            PPC  pFBAOpt_Rxns      ELE_Rxns
# 162        SUCOAS          AKGDH  pFBAOpt_Rxns  pFBAOpt_Rxns
# 163          TALA            RPI      ELE_Rxns      ELE_Rxns
# 164          TALA           TKT1      ELE_Rxns      ELE_Rxns
# 165          TALA           TKT2      ELE_Rxns      ELE_Rxns
